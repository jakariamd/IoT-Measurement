# %%
import subprocess
import os

# Extract DHCP information from PCAP files

def scrape_pcap_dhcp(pcap_file, csv_file):
    bash_command = "tshark -r " + pcap_file + " -Y dhcp.option.hostname -T fields -E separator=, -e eth.src -e dhcp.option.hostname > " + csv_file

    # Execute the Bash command
    process = subprocess.Popen(bash_command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

    # Capture the output and error (if any)
    output, error = process.communicate()

    # Check the return code
    return_code = process.returncode

    if return_code == 0:
        print("Command executed successfully.")
    else:
        print(f"Command failed with return code {return_code}, file: {pcap_file}.")


# Specify the folder path where your pcap files are located
pcap_path = "../../../Validation Data/UNSW/PCAPS/"
csv_path = "../../../Validation Data/UNSW/CSV-DHCP/"

# List to store the file names
pcap_files = []

# Use os.listdir to get a list of files in the folder
files = os.listdir(pcap_path)

# Iterate through the files and filter for pcap files
for file in files:
    if file.endswith(".pcap"):
        # print(pcap_path+file, csv_path+file.split(sep='.')[0] + '.csv')
        scrape_pcap_dhcp(pcap_path+file, csv_path+file.split(sep='.')[0] + '.csv')

# %%
import subprocess
import os

# Extract user agent information from PCAP files

def scrape_pcap_user_agent(pcap_file, csv_file):
    bash_command = "tshark -r " + pcap_file + " -Y http.user_agent -T fields -E separator=, -e eth.src -e http.user_agent > " + csv_file

    # Execute the Bash command
    process = subprocess.Popen(bash_command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

    # Capture the output and error (if any)
    output, error = process.communicate()

    # Check the return code
    return_code = process.returncode

    if return_code == 0:
        print("Command executed successfully.")
    else:
        print(f"Command failed with return code {return_code}, file: {pcap_file}.")


# Specify the folder path where your pcap files are located
pcap_path = "../../../Validation Data/UNSW/PCAPS/"
csv_path = "../../../Validation Data/UNSW/CSV-USER-AGENT/"

# List to store the file names
pcap_files = []

# Use os.listdir to get a list of files in the folder
files = os.listdir(pcap_path)

# Iterate through the files and filter for pcap files
for file in files:
    if file.endswith(".pcap"):
        # print(pcap_path+file, csv_path+file.split(sep='.')[0] + '.csv')
        scrape_pcap_user_agent(pcap_path+file, csv_path+file.split(sep='.')[0] + '.csv')

# %%
import subprocess
import os

# Extract remote endpoints address  from PCAP files

def scrape_pcap_remote_endpoints(pcap_file, csv_file):
    bash_command = "tshark -r " + pcap_file + " -T fields -E separator=, -e eth.src -e ip.src -e ip.dst -e tls.handshake.extensions_server_name > " + csv_file

    # Execute the Bash command
    process = subprocess.Popen(bash_command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

    # Capture the output and error (if any)
    output, error = process.communicate()

    # Check the return code
    return_code = process.returncode

    if return_code == 0:
        print("Command executed successfully.")
    else:
        print(f"Command failed with return code {return_code}, file: {pcap_file}.")


# Specify the folder path where your pcap files are located
pcap_path = "../../../Validation Data/UNSW/PCAPS/"
csv_path = "../../../Validation Data/UNSW/CSV-ENDPOINTS/"

# List to store the file names
pcap_files = []

# Use os.listdir to get a list of files in the folder
files = os.listdir(pcap_path)

# Iterate through the files and filter for pcap files
for file in files:
    if file.endswith(".pcap"):
        # print(pcap_path+file, csv_path+file.split(sep='.')[0] + '.csv')
        scrape_pcap_remote_endpoints(pcap_path+file, csv_path+file.split(sep='.')[0] + '.csv')

# %%
import subprocess
import os

# Extract OUI information from PCAP files

def scrape_pcap_oui(pcap_file, csv_file):
    bash_command = "tshark -r " + pcap_file + " -T fields -E separator=, -e eth.src -e eth.src.oui -e eth.src.oui_resolved > " + csv_file

    # Execute the Bash command
    process = subprocess.Popen(bash_command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

    # Capture the output and error (if any)
    output, error = process.communicate()

    # Check the return code
    return_code = process.returncode

    if return_code == 0:
        print("Command executed successfully.")
    else:
        print(f"Command failed with return code {return_code}, file: {pcap_file}.")

    # return output, return_code


# Specify the folder path where your pcap files are located
pcap_path = "../../../Validation Data/UNSW/PCAPS/"
csv_path = "../../../Validation Data/UNSW/CSV-OUI/"

# List to store the file names
pcap_files = []

# Use os.listdir to get a list of files in the folder
files = os.listdir(pcap_path)

# Iterate through the files and filter for pcap files
for file in files:
    if file.endswith(".pcap"):
        # print(pcap_path+file, csv_path+file.split(sep='.')[0] + '.csv')
        scrape_pcap_oui(pcap_path+file, csv_path+file.split(sep='.')[0] + '.csv')

# %%
import subprocess

# Extract generic information from PCAP files

def scrape_pcap(pcap_file, csv_file): 
    bash_command = "tshark -r " + pcap_file + " -T fields -E separator=, -e eth.src -e eth.src.oui -e eth.src.oui_resolved -e ip.src -e ip.dst -e dhcp.option.hostname -e http.user_agent -e tls.handshake.extensions_server_name > " + csv_file
    
    # Execute the Bash command
    process = subprocess.Popen(bash_command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    
    # Capture the output and error (if any)
    output, error = process.communicate()

    # Check the return code
    return_code = process.returncode

    if return_code == 0:
        print("Command executed successfully.")
    else:
        print(f"Command failed with return code {return_code}, file: {pcap_file}.")

# Specify the folder path where your pcap files are located
pcap_path = "../../../Validation Data/UNSW/PCAPS/"
csv_path = "../../../Validation Data/UNSW/CSV/"

# List to store the file names
pcap_files = []

# Use os.listdir to get a list of files in the folder
files = os.listdir(pcap_path)

# Iterate through the files and filter for pcap files
for file in files:
    if file.endswith(".pcap"):
        # print(pcap_path+file, csv_path+file.split(sep='.')[0] + '.csv')
        scrape_pcap(pcap_path+file, csv_path+file.split(sep='.')[0] + '.csv')

# %%
import subprocess

# Extract MDNS information from PCAP files

def scrape_pcap_mdns(pcap_file, csv_file):
    bash_command = "tshark -r " + pcap_file + " -Y mdns -T fields -E separator=, -e eth.src -e dns.qry.name > " + csv_file

    # Execute the Bash command
    process = subprocess.Popen(bash_command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

    # Capture the output and error (if any)
    output, error = process.communicate()

    # Check the return code
    return_code = process.returncode

    if return_code == 0:
        print("Command executed successfully.")
    else:
        print(f"Command failed with return code {return_code}, file: {pcap_file}.")

    # return output, return_code

# Specify the folder path where your pcap files are located
import os 
pcap_path = "../../../Validation Data/UNSW/PCAPS/"
csv_path = "../../../Validation Data/UNSW/CSV-MDNS/"

# List to store the file names
pcap_files = []

# Use os.listdir to get a list of files in the folder
files = os.listdir(pcap_path)

# Iterate through the files and filter for pcap files
for file in files:
    if file.endswith(".pcap"):
        # print(pcap_path+file, csv_path+file.split(sep='.')[0] + '.csv')
        scrape_pcap_mdns(pcap_path+file, csv_path+file.split(sep='.')[0] + '.csv')

# %%
import subprocess

# Extract SSDP information from PCAP files

def scrape_pcap_ssdp(pcap_file, csv_file):
    bash_command = "tshark -r " + pcap_file + " -Y ssdp -T fields -E separator=, -e eth.src -e http.unknown_header  > " + csv_file

    # Execute the Bash command
    process = subprocess.Popen(bash_command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

    # Capture the output and error (if any)
    output, error = process.communicate()

    # Check the return code
    return_code = process.returncode

    if return_code == 0:
        print("Command executed successfully.")
    else:
        print(f"Command failed with return code {return_code}, file: {pcap_file}.")

    # return output, return_code

# Specify the folder path where your pcap files are located
import os
pcap_path = "../../../Validation Data/UNSW/PCAPS/"
csv_path = "../../../Validation Data/UNSW/CSV-SSDP/"

# List to store the file names
pcap_files = []

# Use os.listdir to get a list of files in the folder
files = os.listdir(pcap_path)

# Iterate through the files and filter for pcap files
for file in files:
    if file.endswith(".pcap"):
        scrape_pcap_ssdp(pcap_path+file, csv_path+file.split(sep='.')[0] + '.csv')

# %%
import subprocess

# Extract UPNP information from PCAP files

def scrape_pcap_upnp(pcap_file, csv_file):
    bash_command = "tshark -r " + pcap_file + " -Y \"udp.dstport == 3483 or tcp.dstport == 3483\" -T fields -E separator=, -e eth.src -e http.file_data  > " + csv_file

    # Execute the Bash command
    process = subprocess.Popen(bash_command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

    # Capture the output and error (if any)
    output, error = process.communicate()

    # Check the return code
    return_code = process.returncode

    if return_code == 0:
        print("Command executed successfully.")
    else:
        print(f"Command failed with return code {return_code}, file: {pcap_file}.")

    # return output, return_code

# Specify the folder path where your pcap files are located
import os
pcap_path = "../../../Validation Data/UNSW/PCAPS/"
csv_path = "../../../Validation Data/UNSW/CSV-UPNP/"

# List to store the file names
pcap_files = []

# Use os.listdir to get a list of files in the folder
files = os.listdir(pcap_path)

# Iterate through the files and filter for pcap files
for file in files:
    if file.endswith(".pcap"):
        scrape_pcap_upnp(pcap_path+file, csv_path+file.split(sep='.')[0] + '.csv')
